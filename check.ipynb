# %%
#!/usr/bin/env python
import os

# Set cache directory under the current directory
cwd = os.getcwd()
cache_dir = os.path.join(cwd, "cache")
os.environ["HF_HOME"] = cache_dir

# Load the dataset
from datasets import load_dataset

review_dataset = load_dataset(
                    "McAuley-Lab/Amazon-Reviews-2023",
                    "raw_review_Home_and_Kitchen",
                    trust_remote_code=True,
                    streaming = True
                )

item_meta_dataset = load_dataset(
                    "McAuley-Lab/Amazon-Reviews-2023",
                    "raw_meta_Home_and_Kitchen",
                    split="full",
                    trust_remote_code=True
                )

# import sqlite3

# con = sqlite3.connect('reviews.db')
# cur = con.cursor()

# res = cur.execute("SELECT * FROM reviews_train WHERE row_id = 1")

# r = res.fetchone()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/rst/miniconda3/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/home/rst/miniconda3/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/home/rst/miniconda3/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_242708/1066278313.py", line 12, in <module>
#     review_dataset = load_dataset(
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/load.py", line 2625, in load_dataset
#     return builder_instance.as_streaming_dataset(split=split)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/builder.py", line 1416, in as_streaming_dataset
#     datasets = map_nested(
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/utils/py_utils.py", line 511, in map_nested
#     mapped = [
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/utils/py_utils.py", line 512, in <listcomp>
#     _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/utils/py_utils.py", line 373, in _single_map_nested
#     return function(data_struct)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/builder.py", line 1432, in _as_streaming_dataset_single
#     return IterableDataset(
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py", line 1741, in __init__
#     self._epoch: Union[int, "torch.Tensor"] = _maybe_share_with_torch_persistent_workers(0)
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/datasets/iterable_dataset.py", line 1698, in _maybe_share_with_torch_persistent_workers
#     import torch
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/home/rst/miniconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /home/rst/miniconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /opt/conda/conda-bld/pytorch_1711403378171/work/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %%
print(len(review_dataset['full']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(len(review_dataset['full']))
#
# TypeError: object of type 'IterableDataset' has no len()
